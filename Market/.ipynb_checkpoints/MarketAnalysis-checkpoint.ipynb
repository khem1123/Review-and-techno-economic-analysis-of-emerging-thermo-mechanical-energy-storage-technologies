# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv( "PTP")
df2 = pd.read_csv("CAES")
df3 = pd.read_csv("CES")
df4 = pd.read_csv("PTES")
df5=pd.read_csv("Bat")

df6=pd.read_csv("PTPReg")
df7=pd.read_csv("CAESReg")
df8=pd.read_csv("CESReg")
df9=pd.read_csv("PTESReg")
df10=pd.read_csv("BatReg")

# %%
import numpy as np
plt.figure()
for i in np.unique(df1.effi)[0:4]:
    plt.plot(df1.energy[df1.effi==i]/1000,df1.power[df1.effi==i]/1000,'o-',label='RT Effi = % 0.2f' % i)
    plt.legend()
plt.title('PTPES')
plt.plot(df5.energy/1000,df5.power/1000,'-o', label='Battery')
plt.xlabel('Energy cost ($/kWh)')
plt.ylabel('Power cost ($/kW)')
plt.grid()
plt.show()

# %%
import numpy as np
plt.figure()
for i in np.unique(df2.effi)[0:7]:
    plt.plot(df2.energy[df2.effi==i]/1000,df2.power[df2.effi==i]/1000,'o-',label='RT Effi = % 0.2f' % i)
    plt.legend()
plt.title('CAES')
plt.plot(df5.energy/1000,df5.power/1000,'-o', label='Battery')
plt.legend()
plt.xlabel('Energy cost ($/kWh)')
plt.ylabel('Power cost ($/kW)')
plt.grid()
plt.show()

# %%
import numpy as np
plt.figure()
for i in np.unique(df3.effi)[0:7]:
    plt.plot(df3.energy[df3.effi==i]/1000,df3.power[df3.effi==i]/1000,'o-',label='RT Effi = % 0.2f' % i)

plt.title('CES')
plt.plot(df5.energy/1000,df5.power/1000,'-o', label='Battery')
plt.legend()
plt.xlabel('Energy cost ($/kWh)')
plt.ylabel('Power cost ($/kW)')
plt.grid()
plt.show()

# %%
import numpy as np
plt.figure()
for i in np.unique(df4.effi)[0:7]:
    plt.plot(df4.energy[df4.effi==i]/1000,df4.power[df4.effi==i]/1000,'o-',label='RT Effi = % 0.2f' % i)
    plt.legend()
plt.title('PTES')
#plt.plot(df5.energy/1000,df5.power/1000,'-o', label='Battery')
plt.legend()
plt.xlabel('Energy cost ($/kWh)')
plt.ylabel('Power cost ($/kW)')
plt.grid()
plt.show()

# %%
import numpy as np
plt.figure()
for i in np.unique(df6.effi):
    plt.plot(df6.energy[df6.effi==i]/1000,df6.power[df6.effi==i]/1000,'o-',label='RT Effi = % 0.2f' % i)
    plt.legend()
plt.title('PTPES (Reg)')
plt.plot(df10.energy/1000,df10.power/1000,'-o', label='Battery')
plt.xlabel('Energy cost ($/kWh)')
plt.ylabel('Power cost ($/kW)')
plt.grid()
plt.show()

# %%
import numpy as np
plt.figure()
for i in np.unique(df7.effi):
    plt.plot(df7.energy[df7.effi==i]/1000,df7.power[df7.effi==i]/1000,'o-',label='RT Effi = % 0.2f' % i)
    plt.legend()
plt.title('CAES (Reg)')
plt.plot(df10.energy/1000,df10.power/1000,'-o', label='Battery')
plt.xlabel('Energy cost ($/kWh)')
plt.ylabel('Power cost ($/kW)')
plt.grid()
plt.show()

# %%
import numpy as np
plt.figure()
for i in np.unique(df8.effi):
    plt.plot(df8.energy[df8.effi==i]/1000,df8.power[df8.effi==i]/1000,'o-',label='RT Effi = % 0.2f' % i)
    plt.legend()
plt.title('CES (Reg)')
plt.plot(df10.energy/1000,df10.power/1000,'-o', label='Battery')
plt.xlabel('Energy cost ($/kWh)')
plt.ylabel('Power cost ($/kW)')
plt.grid()
plt.show()

# %%
import numpy as np
plt.figure()
for i in np.unique(df9.effi):
    plt.plot(df9.energy[df9.effi==i]/1000,df9.power[df9.effi==i]/1000,'o-',label='RT Effi = % 0.2f' % i)
    plt.legend()
plt.title('PTES (Reg)')
plt.plot(df10.energy/1000,df10.power/1000,'-o', label='Battery')
plt.xlabel('Energy cost ($/kWh)')
plt.ylabel('Power cost ($/kW)')
plt.grid()
plt.show()

# %%
fig, axs = plt.subplots(3,2,figsize=(8,10))
fig.suptitle('')
for i in np.unique(df1.effi):
    axs[0,0].plot(df1.energy[df1.effi==i]/1000,df1.power[df1.effi==i]/1000,'o-',label='$\eta_{RT}$ = % 0.2f' % i)
    #axs[0,0].legend()
axs[0,0].set_title('PR = 0.1')
#axs[0,0].set_xlabel('Energy cost ($/kWh)')
axs[0,0].set_ylabel('Power cost ($/kW)')
axs[0,0].grid()

for i in np.unique(df2.effi):
    axs[0,1].plot(df2.energy[df2.effi==i]/1000,df2.power[df2.effi==i]/1000,'o-',label='$\eta_{RT}$ = % 0.2f' % i)
    #axs[0,1].legend()
axs[0,1].set_title('PR = 0.5')
#axs[0,1].set_xlabel('Energy cost ($/kWh)')
#axs[0,1].set_ylabel('Power cost ($/kW)')
axs[0,1].grid()
axs[0,1].sharey(axs[0,0])



for i in np.unique(df1.effi):
    axs[2,0].plot(df1.energy[df1.effi==i]/1000,df1.storage[df1.effi==i],'o-',label='$\eta_{RT}$ = % 0.2f' % i)
    axs[2,0].legend(ncol=1)
axs[2,0].set_xlabel('Energy cost ($/kWh)')
axs[2,0].set_ylabel('Optimum Storage Capacity (MWh)')
axs[2,0].grid()

for i in np.unique(df2.effi):
    axs[2,1].plot(df2.energy[df2.effi==i]/1000,df2.storage[df2.effi==i],'o-',label='$\eta_{RT}$ = % 0.2f' % i)
    axs[2,1].legend(ncol=2)
axs[2,1].set_xlabel('Energy cost ($/kWh)')
axs[2,1].grid()
axs[2,1].sharey(axs[2,0])


for i in np.unique(df1.effi):
    axs[1,0].plot(df1.energy[df1.effi==i]/1000,df1.charge[df1.effi==i],'o-',label='$\eta_{RT}$ = % 0.2f' % i)
    #axs[1,0].legend()
#axs[1,0].set_xlabel('Energy cost ($/kWh)')
axs[1,0].set_ylabel('Optimum Charge Capacity (MW)')
axs[1,0].grid()

for i in np.unique(df2.effi):
    axs[1,1].plot(df2.energy[df2.effi==i]/1000,df2.charge[df2.effi==i],'o-',label='$\eta_{RT}$ = % 0.2f' % i)
   # axs[1,1].legend()
#axs[1,1].set_xlabel('Energy cost ($/kWh)')
axs[1,1].grid()
axs[1,1].sharey(axs[1,0])

# %%
from matplotlib import patches
fig, axs = plt.subplots(2,2,figsize=(8,6))
fig.suptitle('')
for i in np.unique(df1.effi):
    axs[0,0].plot(df1.energy[df1.effi==i]/1000,df1.power[df1.effi==i]/1000,'o-',label='$\eta_{RT}$ = % 0.2f' % i)
    #axs[0,0].legend()
axs[0,0].set_title('Cost charge = 0.1*Cost discharge')
#axs[0,0].set_xlabel('Energy cost ($/kWh)')
axs[0,0].set_ylabel('Power cost ($/kW)')
axs[0,0].grid()

e1 = patches.Ellipse((20, 50), 5, 40,
                     angle=180, linewidth=1, alpha=0.4,facecolor='yellow', edgecolor='yellow', zorder=2)

axs[0,0].add_patch(e1)
axs[0,0].annotate("PTPES", (20, 50), color='black', weight='bold', fontsize=10, ha='center', va='center')



for i in np.unique(df2.effi):
    axs[0,1].plot(df2.energy[df2.effi==i]/1000,df2.power[df2.effi==i]/1000,'o-',label='$\eta_{RT}$ = % 0.2f' % i)
    #axs[0,1].legend(ncol=2)
axs[0,1].set_title('Cost charge = 0.5*Cost discharge')
#axs[0,1].set_xlabel('Energy cost ($/kWh)')
#axs[0,1].set_ylabel('Power cost ($/kW)')
axs[0,1].grid()
axs[0,1].sharey(axs[0,0])
e1 = patches.Ellipse((20, 60), 5, 40,
                     angle=180, linewidth=1, alpha=0.4,facecolor='green', edgecolor='green', zorder=2)

axs[0,1].add_patch(e1)
axs[0,1].annotate("PTES", (20, 60), color='black', weight='bold', fontsize=10, ha='center', va='center')

e2 = patches.Ellipse((40, 55), 20, 40,
                     angle=180, linewidth=1, alpha=0.4,facecolor='red', edgecolor='red', zorder=2)

axs[0,1].add_patch(e2)
axs[0,1].annotate("CES & CAES", (40, 50), color='black', weight='bold', fontsize=10, ha='center', va='center')

for i in np.unique(df1.effi):
    axs[1,0].plot(df1.energy[df1.effi==i]/1000,df1.storage[df1.effi==i],'o-',label='$\eta_{RT}$ = % 0.2f' % i)
    axs[1,0].legend(ncol=1)
axs[1,0].set_xlabel('Energy cost ($/kWh)')
axs[1,0].set_ylabel('Optimum Storage Capacity (MWh)')
axs[1,0].grid()

for i in np.unique(df2.effi):
    axs[1,1].plot(df2.energy[df2.effi==i]/1000,df2.storage[df2.effi==i],'o-',label='$\eta_{RT}$ = % 0.2f' % i)
    axs[1,1].legend(ncol=2)
axs[1,1].set_xlabel('Energy cost ($/kWh)')
axs[1,1].grid()
axs[1,1].sharey(axs[1,0])
plt.tight_layout()

# %%
df=pd.read_csv("Perfect2.csv")

a=np.zeros(len(df.storage))
for i in np.arange(len(df.storage)):
    a[i]=float(df.storage[i].strip("[]"))
df.storage=a
df=df.iloc[1:,]
df=df.drop_duplicates(subset=['energy','effi'], keep='last').reset_index()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator,FormatStrFormatter,MaxNLocator

mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.family'] = 'Arial'

mpl.rcParams['figure.figsize']

df.loc[df.power<= 10100, 'power'] = np.nan
import numpy as np
plt.figure(figsize=(8,4))
for i in np.unique(df.effi):
    plt.plot(df.energy[df.effi==i]/1000,df.power[df.effi==i]/1000,'-o',label='$\eta_{RT}$ = % 0.2f' % i)

    
i=0.7
y2=df.power[df.effi==i]/1000
plt.fill_between(df.energy[df.effi==i]/1000,0,y2,alpha=0.1, hatch="o", edgecolor="b", linewidth=0.0, label= 'Feasible region for $\eta_{RT}$ = 0.70')


#plt.title('Perfect Storage')
plt.xlabel('Energy storage capacity cost ($/kWh)')
plt.ylabel('Power capacity cost ($/kW)')
plt.grid()

plt.errorbar(30, 1500,
             yerr = 500,
             xerr = 15,
             fmt ='sg',elinewidth=2, capsize=5,markersize='10', label= 'Thermo mechanical storages')

plt.errorbar(168, 156,
             yerr = 100,
             xerr = 50,
             fmt ='sk',elinewidth=2,  capsize=5,markersize='10',label='Battery (Lithium-ion)')


plt.legend()

plt.savefig("CurrentMarket.jpg",dpi=600,bbox_inches='tight')
plt.show()
